# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("data.npy")
num_windows = np.load("num_windows.npy")
data.shape
# Out:
# (5, 1000)

# %%
# plt.xlim(left=800)

mean = []
for id, num in enumerate(num_windows):
    mean.append(data[id][800:].mean())
    # plt.plot(data[id], label=num)

plt.scatter(num_windows, mean)

# plt.legend()
