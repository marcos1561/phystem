# %%
import numpy as np
import matplotlib.pyplot as plt

from physical_system.self_propelling import collectors

# %%
# pos_test = np.load("data_test/pos.npy")
# pos_truth = np.load("data_truth/pos.npy")

pos_test = np.load("data_test/only_final/test/pos.npy")
pos_truth = np.load("data_test/only_final/truth2/pos.npy")

# (pos_test == pos_truth).all()
((pos_test - pos_truth)**2).sum()
# Out:
# 5.471422142072319e-26

# %%
pos_test[1].shape

plt.scatter(*pos_truth[0], label="truth")
plt.scatter(*pos_test[0], s=10, label="test")

plt.legend()
plt.show()

# %%
pos, vel, prop_vel, prop_angle, rng, time = collectors.State.load("data_test/only_final/truth")

# %%
# id = 100
# p_id = 10
# n = pos[0][0].size

# sum_force = [0, 0]

# particle = [pos[id][0][p_id], pos[id][1][p_id]]
# for i in range(n):
#     if i == p_id:
#         continue

#     dx = pos[id][0][i] - particle[0]
#     dy = pos[id][1][i] - particle[1]
#     dist = (dx**2 + dy**2)**.5

#     if dist < 5/6:
#         scalar =
# Out:
# 200

# %%
id = 0
p_id = 10

plt.scatter(pos[id][0], pos[id][1])
# plt.scatter([pos[id][0][p_id]], [pos[id][1][p_id]], color="red")
# plt.plot(time, pos[:, 0, 10])

plt.show()
