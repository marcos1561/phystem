# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
with open("data/times.pickle", "rb") as f:
    data = pickle.load(f)

len(data)
# Out:
# 1000

# %%
# data = np.array(data)
plt.plot(data[20:])


print(data[20:].mean()/0.63)
# Out:
# 3.005765517012062
