# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
np.random.choice(range(20), 20)
# Out:
# array([16,  1, 13, 12, 19,  7,  8, 11,  5,  9,  2,  6,  9, 17, 16, 19, 15,
#        11, 13, 11])

# %%
len(cm.tab20b.colors)
# Out:
# 20

# %%
cm.tab20b(4)

num = 100

plt.scatter(range(num), range(num), cmap=cm.tab20b, c=range(num))

# %%
pos = np.random.random((2, 3))
pos
# Out:
# array([[0.93841106, 0.95742435, 0.66757367],
#        [0.41124942, 0.74973901, 0.12641593]])

# %%
pos.flatten()
# Out:
# array([0.93841106, 0.95742435, 0.66757367, 0.41124942, 0.74973901,
#        0.12641593])

# %%
print(pos)
print(pos.reshape(2*3, 2).T[0])
print(pos.reshape(2*3, 2).T[1])
# Out:
# [[[0.76301147 0.38955903]
#   [0.64487447 0.70238163]
#   [0.65417192 0.33569472]]
#
#  [[0.40699126 0.09086447]
#   [0.58840526 0.05492249]
#   [0.81209776 0.89666663]]]
# [0.76301147 0.64487447 0.65417192 0.40699126 0.58840526 0.81209776]
# [0.38955903 0.70238163 0.33569472 0.09086447 0.05492249 0.89666663]
